# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_excel('Pl_Data.xlsx')

# %%
data.head()
# Out:
#    id              name  now_cost position     team  clean_sheets_per_90  \
# 0   3      Granit Xhaka        48      MID  Arsenal                 0.39
# 1   4    Mohamed Elneny        41      MID  Arsenal                 0.00
# 2   5       Rob Holding        42      DEF  Arsenal                 0.00
# 3   6     Thomas Partey        47      MID  Arsenal                 0.40
# 4   7  Martin Ã˜degaard        69      MID  Arsenal                 0.37
#
#    threat_rank_type  expected_assists_per_90  expected_assists  \
# 0                38                     0.12              3.89
# 1               233                     0.03              0.04
# 2               118                     0.02              0.15
# 3                90                     0.08              2.17
# 4                 8                     0.23              8.02
#
#    points_per_game_rank  ...  threat_rank  ep_this  transfers_in  bps  \
# 0                    47  ...           62      7.3        942505  634
# 1                   457  ...          593      0.0        202760   27
# 2                   405  ...          341      0.7         23338  120
# 3                   210  ...          152      1.9        110171  468
# 4                     7  ...           18      6.9       7014051  813
#
#    goals_conceded_per_90  selected_by_percent  influence_rank_type  \
# 0                   1.05                  2.7                   23
# 1                   1.62                  0.6                  226
# 2                   2.08                  0.2                  137
# 3                   1.02                  0.4                   47
# 4                   1.09                 33.3                    3
#
#    points_per_game_rank_type  clean_sheets  now_cost_rank
# 0                         23            13            265
# 1                        201             0            634
# 2                        144             0            598
# 3                         80            11            311
# 4                          3            13             44
#
# [5 rows x 75 columns]

# %%
data.shape
# Out:
# (778, 75)

# %%
data
# Out:
#       id                              name  now_cost position     team  \
# 0      3                      Granit Xhaka        48      MID  Arsenal
# 1      4                    Mohamed Elneny        41      MID  Arsenal
# 2      5                       Rob Holding        42      DEF  Arsenal
# 3      6                     Thomas Partey        47      MID  Arsenal
# 4      7                  Martin Ã˜degaard        69      MID  Arsenal
# ..   ...                               ...       ...      ...      ...
# 773  682  Matheus Santos Carneiro Da Cunha        53      FWD   Wolves
# 774  698                      Mario Lemina        45      MID   Wolves
# 775  704                     Pablo Sarabia        49      MID   Wolves
# 776  717                    Daniel Bentley        40      GKP   Wolves
# 777  721       JoÃ£o Victor Gomes da Silva        45      MID   Wolves
#
#      clean_sheets_per_90  threat_rank_type  expected_assists_per_90  \
# 0                   0.39                38                     0.12
# 1                   0.00               233                     0.03
# 2                   0.00               118                     0.02
# 3                   0.40                90                     0.08
# 4                   0.37                 8                     0.23
# ..                   ...               ...                      ...
# 773                 0.47                46                     0.02
# 774                 0.35               188                     0.03
# 775                 0.35               122                     0.10
# 776                 0.00                32                     0.00
# 777                 0.28               179                     0.02
#
#      expected_assists  points_per_game_rank  ...  threat_rank  ep_this  \
# 0                3.89                    47  ...           62      7.3
# 1                0.04                   457  ...          593      0.0
# 2                0.15                   405  ...          341      0.7
# 3                2.17                   210  ...          152      1.9
# 4                8.02                     7  ...           18      6.9
# ..                ...                   ...  ...          ...      ...
# 773              0.17                   265  ...          169      0.7
# 774              0.46                   355  ...          385      1.5
# 775              0.89                   293  ...          209      0.3
# 776              0.00                   150  ...          521      1.0
# 777              0.11                   337  ...          366      0.5
#
#      transfers_in  bps  goals_conceded_per_90  selected_by_percent  \
# 0          942505  634                   1.05                  2.7
# 1          202760   27                   1.62                  0.6
# 2           23338  120                   2.08                  0.2
# 3          110171  468                   1.02                  0.4
# 4         7014051  813                   1.09                 33.3
# ..            ...  ...                    ...                  ...
# 773         78699  122                   1.12                  0.1
# 774          4325  196                   1.94                  0.0
# 775         50058   57                   1.06                  0.1
# 776          6232   45                   1.50                  0.0
# 777         10923   84                   2.50                  0.0
#
#      influence_rank_type  points_per_game_rank_type  clean_sheets  \
# 0                     23                         23            13
# 1                    226                        201             0
# 2                    137                        144             0
# 3                     47                         80            11
# 4                      3                          3            13
# ..                   ...                        ...           ...
# 773                   40                         36             5
# 774                  125                        146             5
# 775                  164                        116             3
# 776                   32                         25             0
# 777                  144                        135             2
#
#      now_cost_rank
# 0              265
# 1              634
# 2              598
# 3              311
# 4               44
# ..             ...
# 773            153
# 774            359
# 775            225
# 776            651
# 777            395
#
# [778 rows x 75 columns]

# %% [markdown]
# correctiong players cost

# %%
data["now_cost"]=data["now_cost"]/10

# %% [markdown]
# Players with an average 30 minutes per game (30*38 matchs per season)

# %%
filtered_players = data[data['minutes'] > 1140]

# Calculate the average of 'goals_scored' for these players
average_goals_scored = filtered_players['goals_scored'].mean()
average_goals_scored
# Out:
# 3.0734265734265733

# %%
filtered_players.head()
# Out:
#     id              name  now_cost position     team  clean_sheets_per_90  \
# 0    3      Granit Xhaka       4.8      MID  Arsenal                 0.39
# 3    6     Thomas Partey       4.7      MID  Arsenal                 0.40
# 4    7  Martin Ã˜degaard       6.9      MID  Arsenal                 0.37
# 7   10    Benjamin White       5.0      DEF  Arsenal                 0.44
# 10  13       Bukayo Saka       8.0      MID  Arsenal                 0.34
#
#     threat_rank_type  expected_assists_per_90  expected_assists  \
# 0                 38                     0.12              3.89
# 3                 90                     0.08              2.17
# 4                  8                     0.23              8.02
# 7                 38                     0.11              3.60
# 10                 4                     0.17              5.97
#
#     points_per_game_rank  ...  threat_rank  ep_this  transfers_in  bps  \
# 0                     47  ...           62      7.3        942505  634
# 3                    210  ...          152      1.9        110171  468
# 4                      7  ...           18      6.9       7014051  813
# 7                     49  ...          208      3.9       3320417  734
# 10                    12  ...            9      2.6       6134396  678
#
#     goals_conceded_per_90  selected_by_percent  influence_rank_type  \
# 0                    1.05                  2.7                   23
# 3                    1.02                  0.4                   47
# 4                    1.09                 33.3                    3
# 7                    1.03                 16.1                   17
# 10                   1.19                 25.6                    2
#
#     points_per_game_rank_type  clean_sheets  now_cost_rank
# 0                          23            13            265
# 3                          80            11            311
# 4                           3            13             44
# 7                           6            15            197
# 10                          6            12             18
#
# [5 rows x 75 columns]

# %%
high_scorers = data[data['goals_scored'] > average_goals_scored]

# %%
high_scorers
# Out:
#       id                            name  now_cost position      team  \
# 0      3                    Granit Xhaka       4.8      MID   Arsenal
# 4      7                Martin Ã˜degaard       6.9      MID   Arsenal
# 8     11                   Eddie Nketiah       6.3      FWD   Arsenal
# 10    13                     Bukayo Saka       8.0      MID   Arsenal
# 15    19        Gabriel Martinelli Silva       6.5      MID   Arsenal
# ..   ...                             ...       ...      ...       ...
# 720  465                    Jarrod Bowen       8.0      MID  West Ham
# 722  467                     Declan Rice       4.7      MID  West Ham
# 735  603  Lucas Tolentino Coelho de Lima       5.9      MID  West Ham
# 744  480           RÃºben da Silva Neves       5.2      MID    Wolves
# 747  483          Daniel Castelo Podence       5.1      MID    Wolves
#
#      clean_sheets_per_90  threat_rank_type  expected_assists_per_90  \
# 0                   0.39                38                     0.12
# 4                   0.37                 8                     0.23
# 8                   0.17                17                     0.11
# 10                  0.34                 4                     0.17
# 15                  0.45                 3                     0.23
# ..                   ...               ...                      ...
# 720                 0.25                 5                     0.17
# 722                 0.25                97                     0.05
# 735                 0.25                41                     0.11
# 744                 0.30                67                     0.05
# 747                 0.31                30                     0.11
#
#      expected_assists  points_per_game_rank  ...  threat_rank  ep_this  \
# 0                3.89                    47  ...           62      7.3
# 4                8.02                     7  ...           18      6.9
# 8                1.26                   303  ...           43      1.1
# 10               5.97                    12  ...            9      2.6
# 15               6.98                    10  ...            5      0.0
# ..                ...                   ...  ...          ...      ...
# 720              6.00                    75  ...           12      4.0
# 722              1.85                   142  ...          163      3.0
# 735              2.62                   109  ...           65      2.2
# 744              1.57                   116  ...          106      2.3
# 747              2.19                   174  ...           49      0.5
#
#      transfers_in  bps  goals_conceded_per_90  selected_by_percent  \
# 0          942505  634                   1.05                  2.7
# 4         7014051  813                   1.09                 33.3
# 8         1928295  161                   1.34                  1.8
# 10        6134396  678                   1.19                 25.6
# 15        7872522  648                   1.06                 26.3
# ..            ...  ...                    ...                  ...
# 720       1296356  431                   1.39                  3.3
# 722        445046  622                   1.38                  3.2
# 735        371554  395                   1.63                  0.9
# 744        628752  558                   1.43                  1.5
# 747        279685  249                   1.59                  0.7
#
#      influence_rank_type  points_per_game_rank_type  clean_sheets  \
# 0                     23                         23            13
# 4                      3                          3            13
# 8                     33                         42             2
# 10                     2                          6            12
# 15                     9                          5            14
# ..                   ...                        ...           ...
# 720                   26                         33             9
# 722                   13                         57             9
# 735                   50                         47             6
# 744                   11                         49            10
# 747                   77                         69             6
#
#      now_cost_rank
# 0              265
# 4               44
# 8               61
# 10              18
# 15              56
# ..             ...
# 720             16
# 722            318
# 735             75
# 744            161
# 747            176
#
# [100 rows x 75 columns]

# %% [markdown]
# Number of players who scored more than the average: 100

# %%
forwards = high_scorers[high_scorers['position'] == 'FWD']

# %%
forwards.head()
# Out:
#     id                       name  now_cost position         team  \
# 8   11              Eddie Nketiah       6.3      FWD      Arsenal
# 23  28  Gabriel Fernando de Jesus       8.1      FWD      Arsenal
# 46  40              Ollie Watkins       7.3      FWD  Aston Villa
# 83  62              Kieffer Moore       4.9      FWD  Bournemouth
# 87  66            Dominic Solanke       5.6      FWD  Bournemouth
#
#     clean_sheets_per_90  threat_rank_type  expected_assists_per_90  \
# 8                  0.17                17                     0.11
# 23                 0.39                 3                     0.13
# 46                 0.37                 4                     0.08
# 83                 0.21                42                     0.04
# 87                 0.25                 8                     0.07
#
#     expected_assists  points_per_game_rank  ...  threat_rank  ep_this  \
# 8               1.26                   303  ...           43      1.1
# 23              2.91                    15  ...            6      5.3
# 46              2.66                    18  ...            7      3.2
# 83              0.50                   294  ...          138      0.3
# 87              2.30                    67  ...           13      2.5
#
#     transfers_in  bps  goals_conceded_per_90  selected_by_percent  \
# 8        1928295  161                   1.34                  1.8
# 23       3780822  401                   1.00                 28.3
# 46       4129586  550                   1.15                 12.8
# 83        437532  161                   2.41                  0.7
# 87       2006010  339                   1.63                  3.6
#
#     influence_rank_type  points_per_game_rank_type  clean_sheets  \
# 8                    33                         42             2
# 23                    7                          5             9
# 46                    4                          6            13
# 83                   32                         39             3
# 87                   10                         11             8
#
#     now_cost_rank
# 8              61
# 23             14
# 46             30
# 83            230
# 87             92
#
# [5 rows x 75 columns]

# %%
# Calculate the percentage of forwards among all high scorers
percentage_forwards = (len(forwards) / len(high_scorers)) * 100

print(f"Percentage of forwards among high scorers: {percentage_forwards:.2f}%")
# Out:
# Percentage of forwards among high scorers: 33.00%

# %%
grouped = forwards.groupby(['goals_scored', 'now_cost']).size().reset_index(name='count')


dot_size = grouped['count'] * 50 

# Create a scatter plot with scaled dot size
plt.figure(figsize=(10, 6))
plt.scatter( grouped['now_cost'],grouped['goals_scored'], s=dot_size, color='blue', alpha=0.7)
plt.title('Goals Scored vs. Now Cost')
plt.ylabel('Goals Scored')
plt.xlabel('Now Cost')
plt.title('Goals Scored vs. Cost for Forward Players')
plt.text(5.5, 35, 'Conclusion: As goals scored increase, the cost tends to increase', fontsize=12, color='red')
# Out:
# Text(5.5, 35, 'Conclusion: As goals scored increase, the cost tends to increase')

# %%
midfielders = high_scorers[high_scorers['position'] == 'MID']

# Calculate the percentage of forwards among all high scorers
percentage_midfielders = (len(midfielders) / len(high_scorers)) * 100

# %%
midfielders.head()
# Out:
#      id                      name  now_cost position     team  \
# 0     3              Granit Xhaka       4.8      MID  Arsenal
# 4     7          Martin Ã˜degaard       6.9      MID  Arsenal
# 10   13               Bukayo Saka       8.0      MID  Arsenal
# 15   19  Gabriel Martinelli Silva       6.5      MID  Arsenal
# 24  111          Leandro Trossard       6.6      MID  Arsenal
#
#     clean_sheets_per_90  threat_rank_type  expected_assists_per_90  \
# 0                  0.39                38                     0.12
# 4                  0.37                 8                     0.23
# 10                 0.34                 4                     0.17
# 15                 0.45                 3                     0.23
# 24                 0.32                11                     0.24
#
#     expected_assists  points_per_game_rank  ...  threat_rank  ep_this  \
# 0               3.89                    47  ...           62      7.3
# 4               8.02                     7  ...           18      6.9
# 10              5.97                    12  ...            9      2.6
# 15              6.98                    10  ...            5      0.0
# 24              6.02                    32  ...           22      2.6
#
#     transfers_in  bps  goals_conceded_per_90  selected_by_percent  \
# 0         942505  634                   1.05                  2.7
# 4        7014051  813                   1.09                 33.3
# 10       6134396  678                   1.19                 25.6
# 15       7872522  648                   1.06                 26.3
# 24       5012558  494                   1.53                  7.2
#
#     influence_rank_type  points_per_game_rank_type  clean_sheets  \
# 0                    23                         23            13
# 4                     3                          3            13
# 10                    2                          6            12
# 15                    9                          5            14
# 24                   28                         14             8
#
#     now_cost_rank
# 0             265
# 4              44
# 10             18
# 15             56
# 24             49
#
# [5 rows x 75 columns]

# %%
print(f"Percentage of forwards among high scorers: {percentage_midfielders:.2f}%")
# Out:
# Percentage of forwards among high scorers: 67.00%

# %%
grouped = midfielders.groupby(['goals_scored', 'now_cost']).size().reset_index(name='count')


dot_size = grouped['count'] * 50 

# Create a scatter plot with scaled dot size
plt.figure(figsize=(10, 6))
plt.scatter(grouped['now_cost'],grouped['goals_scored'], s=dot_size, color='blue', alpha=0.7)
plt.title('Goals Scored vs. Now Cost')
plt.ylabel('Goals Scored')
plt.xlabel('Now Cost')
plt.title('Goals Scored vs. Cost for Midfielders Players')
plt.text(5, 18, 'Conclusion: As goals scored increase, the cost tends to increase', fontsize=12, color='red')
# Out:
# Text(5, 18, 'Conclusion: As goals scored increase, the cost tends to increase')

# %%
defenders = high_scorers[high_scorers['position'] == 'DEF']

# Calculate the percentage of forwards among all high scorers
percentage_defenders = (len(defenders) / len(high_scorers)) * 100



print(f"Percentage of forwards among high scorers: {percentage_defenders:.2f}%")
# Out:
# Percentage of forwards among high scorers: 0.00%

# %%
more_than_expected = filtered_players[filtered_players['goals_scored'] > filtered_players['expected_goals']]

# %%
grouped = more_than_expected.groupby(['goals_scored', 'now_cost']).size().reset_index(name='count')


dot_size = grouped['count'] * 50 

# Create a scatter plot with scaled dot size
plt.figure(figsize=(10, 6))
plt.scatter(grouped['now_cost'],grouped['goals_scored'], s=dot_size, color='blue', alpha=0.7)
plt.title('Goals Scored vs. Now Cost')
plt.ylabel('Goals Scored')
plt.xlabel('Now Cost')
plt.title('Goals Scored vs. Cost for players who scored more than expected')
plt.text(5, 35, 'Conclusion: As goals scored increase, the cost tends to increase', fontsize=12, color='red')
# Out:
# Text(5, 35, 'Conclusion: As goals scored increase, the cost tends to increase')

# %%
more_than_expected[['name','goals_scored','expected_goals','now_cost','position']]
# Out:
#                             name  goals_scored  expected_goals  now_cost  \
# 0                   Granit Xhaka             7            4.65       4.8
# 3                  Thomas Partey             3            2.59       4.7
# 4               Martin Ã˜degaard            15            9.75       6.9
# 7                 Benjamin White             2            1.25       5.0
# 10                   Bukayo Saka            14           11.49       8.0
# ..                           ...           ...             ...       ...
# 730  Emerson Palmieri dos Santos             1            0.80       4.0
# 742         Jonathan Castro Otto             1            0.30       4.3
# 744        RÃºben da Silva Neves             6            5.19       5.2
# 747       Daniel Castelo Podence             6            3.88       5.1
# 755         Adama TraorÃ© Diarra             2            1.38       5.3
#
#     position
# 0        MID
# 3        MID
# 4        MID
# 7        DEF
# 10       MID
# ..       ...
# 730      DEF
# 742      DEF
# 744      MID
# 747      MID
# 755      MID
#
# [106 rows x 5 columns]

# %%
more_than_expected_forwards=more_than_expected[more_than_expected['position']=='FWD']
more_than_expected_midfielders=more_than_expected[more_than_expected['position']=='MID']
more_than_expected_defenders=more_than_expected[more_than_expected['position']=='DEF']
print('percentage of forwards who scored more than expected',(len(more_than_expected_forwards) / len(more_than_expected)) * 100,'%') 
print('percentage of midfielders who scored more than expected',(len(more_than_expected_midfielders) / len(more_than_expected)) * 100,'%') 
print('percentage of defenders who scored more than expected', (len(more_than_expected_defenders) / len(more_than_expected)) * 100,'%')
# Out:
# percentage of forwards who scored more than expected 10.377358490566039 %
# percentage of midfielders who scored more than expected 56.60377358490566 %
# percentage of defenders who scored more than expected 33.0188679245283 %

# %% [markdown]
# Midfielders are more likely to score than expected

# %%
arsenal_data = data[data['team'] == 'Arsenal']
Liverpool_data = data[data['team'] == 'Liverpool']
Mancity_data = data[data['team'] == 'Manchester city']
Manutd_data = data[data['team'] == 'Manchester united']
chelsea_data = data[data['team'] == 'Chelsea']
tottenham_data = data[data['team'] == 'Tottenham']

# %%
Liverpool_data["goals_scored"].mean()
# Out:
# 1.9722222222222223
