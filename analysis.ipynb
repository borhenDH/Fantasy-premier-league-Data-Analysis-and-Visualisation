# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_excel('Pl_Data.xlsx')

# %%
data.head()
# Out:
#    id              name  now_cost position     team  clean_sheets_per_90  \
# 0   3      Granit Xhaka        48      MID  Arsenal                 0.39
# 1   4    Mohamed Elneny        41      MID  Arsenal                 0.00
# 2   5       Rob Holding        42      DEF  Arsenal                 0.00
# 3   6     Thomas Partey        47      MID  Arsenal                 0.40
# 4   7  Martin Ã˜degaard        69      MID  Arsenal                 0.37
#
#    threat_rank_type  expected_assists_per_90  expected_assists  \
# 0                38                     0.12              3.89
# 1               233                     0.03              0.04
# 2               118                     0.02              0.15
# 3                90                     0.08              2.17
# 4                 8                     0.23              8.02
#
#    points_per_game_rank  ...  threat_rank  ep_this  transfers_in  bps  \
# 0                    47  ...           62      7.3        942505  634
# 1                   457  ...          593      0.0        202760   27
# 2                   405  ...          341      0.7         23338  120
# 3                   210  ...          152      1.9        110171  468
# 4                     7  ...           18      6.9       7014051  813
#
#    goals_conceded_per_90  selected_by_percent  influence_rank_type  \
# 0                   1.05                  2.7                   23
# 1                   1.62                  0.6                  226
# 2                   2.08                  0.2                  137
# 3                   1.02                  0.4                   47
# 4                   1.09                 33.3                    3
#
#    points_per_game_rank_type  clean_sheets  now_cost_rank
# 0                         23            13            265
# 1                        201             0            634
# 2                        144             0            598
# 3                         80            11            311
# 4                          3            13             44
#
# [5 rows x 75 columns]

# %%
data.shape
# Out:
# (778, 75)

# %%
data
# Out:
#       id                              name  now_cost position     team  \
# 0      3                      Granit Xhaka        48      MID  Arsenal
# 1      4                    Mohamed Elneny        41      MID  Arsenal
# 2      5                       Rob Holding        42      DEF  Arsenal
# 3      6                     Thomas Partey        47      MID  Arsenal
# 4      7                  Martin Ã˜degaard        69      MID  Arsenal
# ..   ...                               ...       ...      ...      ...
# 773  682  Matheus Santos Carneiro Da Cunha        53      FWD   Wolves
# 774  698                      Mario Lemina        45      MID   Wolves
# 775  704                     Pablo Sarabia        49      MID   Wolves
# 776  717                    Daniel Bentley        40      GKP   Wolves
# 777  721       JoÃ£o Victor Gomes da Silva        45      MID   Wolves
#
#      clean_sheets_per_90  threat_rank_type  expected_assists_per_90  \
# 0                   0.39                38                     0.12
# 1                   0.00               233                     0.03
# 2                   0.00               118                     0.02
# 3                   0.40                90                     0.08
# 4                   0.37                 8                     0.23
# ..                   ...               ...                      ...
# 773                 0.47                46                     0.02
# 774                 0.35               188                     0.03
# 775                 0.35               122                     0.10
# 776                 0.00                32                     0.00
# 777                 0.28               179                     0.02
#
#      expected_assists  points_per_game_rank  ...  threat_rank  ep_this  \
# 0                3.89                    47  ...           62      7.3
# 1                0.04                   457  ...          593      0.0
# 2                0.15                   405  ...          341      0.7
# 3                2.17                   210  ...          152      1.9
# 4                8.02                     7  ...           18      6.9
# ..                ...                   ...  ...          ...      ...
# 773              0.17                   265  ...          169      0.7
# 774              0.46                   355  ...          385      1.5
# 775              0.89                   293  ...          209      0.3
# 776              0.00                   150  ...          521      1.0
# 777              0.11                   337  ...          366      0.5
#
#      transfers_in  bps  goals_conceded_per_90  selected_by_percent  \
# 0          942505  634                   1.05                  2.7
# 1          202760   27                   1.62                  0.6
# 2           23338  120                   2.08                  0.2
# 3          110171  468                   1.02                  0.4
# 4         7014051  813                   1.09                 33.3
# ..            ...  ...                    ...                  ...
# 773         78699  122                   1.12                  0.1
# 774          4325  196                   1.94                  0.0
# 775         50058   57                   1.06                  0.1
# 776          6232   45                   1.50                  0.0
# 777         10923   84                   2.50                  0.0
#
#      influence_rank_type  points_per_game_rank_type  clean_sheets  \
# 0                     23                         23            13
# 1                    226                        201             0
# 2                    137                        144             0
# 3                     47                         80            11
# 4                      3                          3            13
# ..                   ...                        ...           ...
# 773                   40                         36             5
# 774                  125                        146             5
# 775                  164                        116             3
# 776                   32                         25             0
# 777                  144                        135             2
#
#      now_cost_rank
# 0              265
# 1              634
# 2              598
# 3              311
# 4               44
# ..             ...
# 773            153
# 774            359
# 775            225
# 776            651
# 777            395
#
# [778 rows x 75 columns]

# %%
data["now_cost"]=data["now_cost"]/10

# %% [markdown]
# Players with an average 30 minutes per game

# %%
filtered_players = data[data['minutes'] > 1140]

# Calculate the average of 'goals_scored' for these players
average_goals_scored = filtered_players['goals_scored'].mean()
average_goals_scored
# Out:
# 3.0734265734265733

# %%
high_scorers = data[data['goals_scored'] > average_goals_scored]
print(high_scorers)

count_high_scorers = len(high_scorers)
print(f"Number of players who scored more than the average: {count_high_scorers}")
# Out:
#       id                            name  now_cost position      team  \
# 0      3                    Granit Xhaka       4.8      MID   Arsenal
# 4      7                Martin Ã˜degaard       6.9      MID   Arsenal
# 8     11                   Eddie Nketiah       6.3      FWD   Arsenal
# 10    13                     Bukayo Saka       8.0      MID   Arsenal
# 15    19        Gabriel Martinelli Silva       6.5      MID   Arsenal
# ..   ...                             ...       ...      ...       ...
# 720  465                    Jarrod Bowen       8.0      MID  West Ham
# 722  467                     Declan Rice       4.7      MID  West Ham
# 735  603  Lucas Tolentino Coelho de Lima       5.9      MID  West Ham
# 744  480           RÃºben da Silva Neves       5.2      MID    Wolves
# 747  483          Daniel Castelo Podence       5.1      MID    Wolves
#
#      clean_sheets_per_90  threat_rank_type  expected_assists_per_90  \
# 0                   0.39                38                     0.12
# 4                   0.37                 8                     0.23
# 8                   0.17                17                     0.11
# 10                  0.34                 4                     0.17
# 15                  0.45                 3                     0.23
# ..                   ...               ...                      ...
# 720                 0.25                 5                     0.17
# 722                 0.25                97                     0.05
# 735                 0.25                41                     0.11
# 744                 0.30                67                     0.05
# 747                 0.31                30                     0.11
#
#      expected_assists  points_per_game_rank  ...  threat_rank  ep_this  \
# 0                3.89                    47  ...           62      7.3
# 4                8.02                     7  ...           18      6.9
# 8                1.26                   303  ...           43      1.1
# 10               5.97                    12  ...            9      2.6
# 15               6.98                    10  ...            5      0.0
# ..                ...                   ...  ...          ...      ...
# 720              6.00                    75  ...           12      4.0
# 722              1.85                   142  ...          163      3.0
# 735              2.62                   109  ...           65      2.2
# 744              1.57                   116  ...          106      2.3
# 747              2.19                   174  ...           49      0.5
#
#      transfers_in  bps  goals_conceded_per_90  selected_by_percent  \
# 0          942505  634                   1.05                  2.7
# 4         7014051  813                   1.09                 33.3
# 8         1928295  161                   1.34                  1.8
# 10        6134396  678                   1.19                 25.6
# 15        7872522  648                   1.06                 26.3
# ..            ...  ...                    ...                  ...
# 720       1296356  431                   1.39                  3.3
# 722        445046  622                   1.38                  3.2
# 735        371554  395                   1.63                  0.9
# 744        628752  558                   1.43                  1.5
# 747        279685  249                   1.59                  0.7
#
#      influence_rank_type  points_per_game_rank_type  clean_sheets  \
# 0                     23                         23            13
# 4                      3                          3            13
# 8                     33                         42             2
# 10                     2                          6            12
# 15                     9                          5            14
# ..                   ...                        ...           ...
# 720                   26                         33             9
# 722                   13                         57             9
# 735                   50                         47             6
# 744                   11                         49            10
# 747                   77                         69             6
#
#      now_cost_rank
# 0              265
# 4               44
# 8               61
# 10              18
# 15              56
# ..             ...
# 720             16
# 722            318
# 735             75
# 744            161
# 747            176
#
# [100 rows x 75 columns]
# Number of players who scored more than the average: 100

# %%
forwards = high_scorers[high_scorers['position'] == 'FWD']

# Calculate the percentage of forwards among all high scorers
percentage_forwards = (len(forwards) / len(high_scorers)) * 100

print(forwards)

print(f"Percentage of forwards among high scorers: {percentage_forwards:.2f}%")
# Out:
#       id                           name  now_cost position            team  \
# 8     11                  Eddie Nketiah       6.3      FWD         Arsenal
# 23    28      Gabriel Fernando de Jesus       8.1      FWD         Arsenal
# 46    40                  Ollie Watkins       7.3      FWD     Aston Villa
# 83    62                  Kieffer Moore       4.9      FWD     Bournemouth
# 87    66                Dominic Solanke       5.6      FWD     Bournemouth
# 122   80                     Ivan Toney       7.1      FWD       Brentford
# 137   95                   Bryan Mbeumo       5.7      FWD       Brentford
# 159  103                  Danny Welbeck       6.5      FWD        Brighton
# 175  123                    Deniz Undav       5.0      FWD        Brighton
# 177  125                   Julio Enciso       4.6      FWD        Brighton
# 185  596                  Evan Ferguson       4.6      FWD        Brighton
# 215  145                    Kai Havertz       7.4      FWD         Chelsea
# 233  690          JoÃ£o FÃ©lix Sequeira       7.1      FWD         Chelsea
# 254  166                Odsonne Edouard       5.0      FWD  Crystal Palace
# 332  210           Aleksandar MitroviÄ‡       6.6      FWD          Fulham
# 353  618  Carlos VinÃ­cius Alves Morais       5.4      FWD          Fulham
# 375  262              Kelechi Iheanacho       5.8      FWD       Leicester
# 384  271                    Patson Daka       5.6      FWD       Leicester
# 403  227                Patrick Bamford       7.1      FWD           Leeds
# 441  279                Roberto Firmino       8.0      FWD       Liverpool
# 450  288        Diogo Teixeira da Silva       8.6      FWD       Liverpool
# 458  297         Darwin NÃºÃ±ez Ribeiro       8.6      FWD       Liverpool
# 489  318                 Erling Haaland      12.4      FWD        Man City
# 490  319               JuliÃ¡n Ãlvarez       6.1      FWD        Man City
# 526  345                Anthony Martial       6.3      FWD         Man Utd
# 551  356                  Callum Wilson       7.3      FWD       Newcastle
# 575  594                 Alexander Isak       7.0      FWD       Newcastle
# 599  394                Brennan Johnson       5.5      FWD   Nott'm Forest
# 602  397                  Taiwo Awoniyi       5.6      FWD   Nott'm Forest
# 641  411                      Che Adams       6.0      FWD     Southampton
# 673  427                     Harry Kane      11.5      FWD           Spurs
# 710   30                     Danny Ings       6.3      FWD        West Ham
# 714  458                Michail Antonio       6.9      FWD        West Ham
#
#      clean_sheets_per_90  threat_rank_type  expected_assists_per_90  \
# 8                   0.17                17                     0.11
# 23                  0.39                 3                     0.13
# 46                  0.37                 4                     0.08
# 83                  0.21                42                     0.04
# 87                  0.25                 8                     0.07
# 122                 0.30                 5                     0.11
# 137                 0.31                11                     0.17
# 159                 0.29                13                     0.08
# 175                 0.29                36                     0.18
# 177                 0.45                32                     0.13
# 185                 0.57                34                     0.05
# 215                 0.32                10                     0.10
# 233                 0.19                38                     0.10
# 254                 0.25                22                     0.04
# 332                 0.31                 6                     0.06
# 353                 0.08                33                     0.06
# 375                 0.08                26                     0.13
# 384                 0.38                25                     0.13
# 403                 0.06                18                     0.05
# 441                 0.30                12                     0.16
# 450                 0.40                35                     0.14
# 458                 0.37                 7                     0.14
# 489                 0.42                 1                     0.10
# 490                 0.31                21                     0.10
# 526                 0.65                31                     0.14
# 551                 0.48                 9                     0.10
# 575                 0.24                15                     0.08
# 599                 0.22                14                     0.06
# 602                 0.32                30                     0.02
# 641                 0.18                19                     0.10
# 673                 0.29                 2                     0.11
# 710                 0.28                16                     0.07
# 714                 0.25                20                     0.03
#
#      expected_assists  points_per_game_rank  ...  threat_rank  ep_this  \
# 8                1.26                   303  ...           43      1.1
# 23               2.91                    15  ...            6      5.3
# 46               2.66                    18  ...            7      3.2
# 83               0.50                   294  ...          138      0.3
# 87               2.30                    67  ...           13      2.5
# 122              3.72                    11  ...            8      0.0
# 137              5.53                    68  ...           21      6.8
# 159              1.65                   177  ...           28      1.1
# 175              1.25                   249  ...          110      3.1
# 177              1.18                   170  ...           98      2.9
# 185              0.54                   115  ...          105      2.9
# 215              2.75                   178  ...           15      0.8
# 233              0.99                   193  ...          126      1.8
# 254              0.80                   262  ...           54      3.0
# 332              1.31                    22  ...           10      2.8
# 353              0.72                   215  ...           99      4.8
# 375              1.56                   176  ...           75      1.2
# 384              1.69                   266  ...           73      1.4
# 403              0.90                   235  ...           47      1.1
# 441              2.16                    43  ...           27      3.0
# 450              1.70                    97  ...          108      4.7
# 458              2.66                   120  ...           11      1.7
# 489              3.11                     2  ...            1      5.4
# 490              1.63                   125  ...           53      5.1
# 526              1.46                   148  ...           96      3.0
# 551              2.11                    14  ...           14      7.3
# 575              1.37                    23  ...           33      3.7
# 599              2.00                   138  ...           30      3.0
# 602              0.29                    84  ...           95      9.5
# 641              2.19                   118  ...           48      0.0
# 673              4.01                     4  ...            2      9.2
# 710              1.27                   191  ...           41      2.2
# 714              0.58                   234  ...           52      1.2
#
#      transfers_in   bps  goals_conceded_per_90  selected_by_percent  \
# 8         1928295   161                   1.34                  1.8
# 23        3780822   401                   1.00                 28.3
# 46        4129586   550                   1.15                 12.8
# 83         437532   161                   2.41                  0.7
# 87        2006010   339                   1.63                  3.6
# 122      10688278   607                   1.28                 18.2
# 137       1501560   556                   1.21                  4.0
# 159        682148   296                   1.37                  2.1
# 175        123408   173                   1.32                  0.8
# 177        356708   189                   1.36                  2.4
# 185        625820   213                   1.15                  1.7
# 215       1575452   301                   1.09                  3.2
# 233        910337   126                   1.54                  1.7
# 254        877397   225                   1.26                  2.0
# 332       7802867   324                   1.34                 12.5
# 353        122045   206                   1.64                  0.5
# 375        377387   237                   1.86                  0.9
# 384        255028   231                   1.85                  0.8
# 403        190355   157                   1.85                  0.4
# 441       1942888   447                   1.27                  3.2
# 450        845827   282                   1.52                  2.0
# 458       4112461   310                   1.18                  6.4
# 489       7833248  1040                   0.85                 78.4
# 490       1407829   393                   0.99                  7.7
# 526       1586178   230                   0.74                  2.9
# 551       4424113   526                   0.77                 17.2
# 575       3288916   353                   1.18                 12.7
# 599        648132   384                   1.66                  1.6
# 602        282041   320                   1.87                  1.2
# 641        539048   262                   1.86                  0.8
# 673       7381740  1008                   1.64                 32.7
# 710        574778   317                   1.48                  1.4
# 714        326532   222                   1.43                  1.5
#
#      influence_rank_type  points_per_game_rank_type  clean_sheets  \
# 8                     33                         42             2
# 23                     7                          5             9
# 46                     4                          6            13
# 83                    32                         39             3
# 87                    10                         11             8
# 122                    3                          3            10
# 137                    6                         12            10
# 159                   17                         23             6
# 175                   37                         31             2
# 177                   29                         21             4
# 185                   27                         15             6
# 215                   13                         24             9
# 233                   34                         26             2
# 254                   19                         35             5
# 332                    8                          7             7
# 353                   31                         27             1
# 375                   21                         22             1
# 384                   25                         37             5
# 403                   30                         30             1
# 441                    9                          9             4
# 450                   24                         14             5
# 458                   14                         17             7
# 489                    1                          1            13
# 490                   15                         18             5
# 526                   23                         20             7
# 551                    5                          4            10
# 575                   12                          8             4
# 599                   11                         19             7
# 602                   18                         13             5
# 641                   20                         16             4
# 673                    2                          2            11
# 710                   16                         25             5
# 714                   22                         29             5
#
#      now_cost_rank
# 8               61
# 23              14
# 46              30
# 83             230
# 87              92
# 122             38
# 137             86
# 159             53
# 175            213
# 177            337
# 185            339
# 215             28
# 233             40
# 254            198
# 332             50
# 353            129
# 375             77
# 384            101
# 403             35
# 441             15
# 450             10
# 458             11
# 489              2
# 490             67
# 526             60
# 551             29
# 575             41
# 599            113
# 602             96
# 641             71
# 673              4
# 710             59
# 714             43
#
# [33 rows x 75 columns]
# Percentage of forwards among high scorers: 33.00%

# %%
grouped = forwards.groupby(['goals_scored', 'now_cost']).size().reset_index(name='count')


dot_size = grouped['count'] * 50 

# Create a scatter plot with scaled dot size
plt.figure(figsize=(10, 6))
plt.scatter(grouped['goals_scored'], grouped['now_cost'], s=dot_size, color='blue', alpha=0.7)
plt.title('Goals Scored vs. Now Cost')
plt.xlabel('Goals Scored')
plt.ylabel('Now Cost')
plt.title('Goals Scored vs. Cost for Forward Players')
# Out:
# Text(0.5, 1.0, 'Goals Scored vs. Cost for Forward Players')

# %%
midfielders = high_scorers[high_scorers['position'] == 'MID']

# Calculate the percentage of forwards among all high scorers
percentage_midfielders = (len(midfielders) / len(high_scorers)) * 100

print(midfielders)

print(f"Percentage of forwards among high scorers: {percentage_midfielders:.2f}%")
# Out:
#       id                            name  now_cost position      team  \
# 0      3                    Granit Xhaka       4.8      MID   Arsenal
# 4      7                Martin Ã˜degaard       6.9      MID   Arsenal
# 10    13                     Bukayo Saka       8.0      MID   Arsenal
# 15    19        Gabriel Martinelli Silva       6.5      MID   Arsenal
# 24   111                Leandro Trossard       6.6      MID   Arsenal
# ..   ...                             ...       ...      ...       ...
# 720  465                    Jarrod Bowen       8.0      MID  West Ham
# 722  467                     Declan Rice       4.7      MID  West Ham
# 735  603  Lucas Tolentino Coelho de Lima       5.9      MID  West Ham
# 744  480           RÃºben da Silva Neves       5.2      MID    Wolves
# 747  483          Daniel Castelo Podence       5.1      MID    Wolves
#
#      clean_sheets_per_90  threat_rank_type  expected_assists_per_90  \
# 0                   0.39                38                     0.12
# 4                   0.37                 8                     0.23
# 10                  0.34                 4                     0.17
# 15                  0.45                 3                     0.23
# 24                  0.32                11                     0.24
# ..                   ...               ...                      ...
# 720                 0.25                 5                     0.17
# 722                 0.25                97                     0.05
# 735                 0.25                41                     0.11
# 744                 0.30                67                     0.05
# 747                 0.31                30                     0.11
#
#      expected_assists  points_per_game_rank  ...  threat_rank  ep_this  \
# 0                3.89                    47  ...           62      7.3
# 4                8.02                     7  ...           18      6.9
# 10               5.97                    12  ...            9      2.6
# 15               6.98                    10  ...            5      0.0
# 24               6.02                    32  ...           22      2.6
# ..                ...                   ...  ...          ...      ...
# 720              6.00                    75  ...           12      4.0
# 722              1.85                   142  ...          163      3.0
# 735              2.62                   109  ...           65      2.2
# 744              1.57                   116  ...          106      2.3
# 747              2.19                   174  ...           49      0.5
#
#      transfers_in  bps  goals_conceded_per_90  selected_by_percent  \
# 0          942505  634                   1.05                  2.7
# 4         7014051  813                   1.09                 33.3
# 10        6134396  678                   1.19                 25.6
# 15        7872522  648                   1.06                 26.3
# 24        5012558  494                   1.53                  7.2
# ..            ...  ...                    ...                  ...
# 720       1296356  431                   1.39                  3.3
# 722        445046  622                   1.38                  3.2
# 735        371554  395                   1.63                  0.9
# 744        628752  558                   1.43                  1.5
# 747        279685  249                   1.59                  0.7
#
#      influence_rank_type  points_per_game_rank_type  clean_sheets  \
# 0                     23                         23            13
# 4                      3                          3            13
# 10                     2                          6            12
# 15                     9                          5            14
# 24                    28                         14             8
# ..                   ...                        ...           ...
# 720                   26                         33             9
# 722                   13                         57             9
# 735                   50                         47             6
# 744                   11                         49            10
# 747                   77                         69             6
#
#      now_cost_rank
# 0              265
# 4               44
# 10              18
# 15              56
# 24              49
# ..             ...
# 720             16
# 722            318
# 735             75
# 744            161
# 747            176
#
# [67 rows x 75 columns]
# Percentage of forwards among high scorers: 67.00%

# %%
plt.figure(figsize=(10, 6))
scatter = plt.scatter(data['goals_scored'], data['now_cost'], c=data.index, cmap='viridis', s=100, alpha=0.7)
plt.xlabel('Goals Scored')
plt.ylabel('Cost')
plt.title('Goals Scored vs. Cost for Midfielders Players')
legend1 = plt.colorbar(scatter)
legend1.set_label('Player Index')

# %%
defenders = high_scorers[high_scorers['position'] == 'DEF']

# Calculate the percentage of forwards among all high scorers
percentage_defenders = (len(defenders) / len(high_scorers)) * 100

print(defenders)

print(f"Percentage of forwards among high scorers: {percentage_defenders:.2f}%")
# Out:
# Empty DataFrame
# Columns: [id, name, now_cost, position, team, clean_sheets_per_90, threat_rank_type, expected_assists_per_90, expected_assists, points_per_game_rank, goals_scored, penalties_missed, creativity_rank_type, transfers_out, value_form, direct_freekicks_order, value_season, bonus, starts_per_90, cost_change_start, news_added, expected_goals_conceded, cost_change_start_fall, expected_goals_conceded_per_90, red_cards, threat, selected_rank_type, influence, penalties_saved, corners_and_indirect_freekicks_order, ep_next, event_points, web_name, creativity, ict_index_rank, saves_per_90, creativity_rank, expected_goals, own_goals, status, now_cost_rank_type, saves, yellow_cards, goals_conceded, news, expected_goal_involvements_per_90, assists, form_rank_type, ict_index_rank_type, chance_of_playing_next_round, influence_rank, penalties_order, ict_index, form, dreamteam_count, expected_goal_involvements, chance_of_playing_this_round, starts, points_per_game, minutes, total_points, in_dreamteam, form_rank, selected_rank, expected_goals_per_90, threat_rank, ep_this, transfers_in, bps, goals_conceded_per_90, selected_by_percent, influence_rank_type, points_per_game_rank_type, clean_sheets, now_cost_rank]
# Index: []
#
# [0 rows x 75 columns]
# Percentage of forwards among high scorers: 0.00%

# %%
arsenal_data = data[data['team'] == 'Arsenal']
Liverpool_data = data[data['team'] == 'Liverpool']
Mancity_data = data[data['team'] == 'Manchester city']
Manutd_data = data[data['team'] == 'Manchester united']
chelsea_data = data[data['team'] == 'Chelsea']
tottenham_data = data[data['team'] == 'Tottenham']

# %%
Liverpool_data["goals_scored"].mean()
# Out:
# 1.9722222222222223
